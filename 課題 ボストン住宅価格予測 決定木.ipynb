# %%
#データを取得する
from sklearn.datasets import load_boston
boston = load_boston()

# %%
#取得データをDataFrameにする
import pandas as pd
X = pd.DataFrame(boston.data,columns=boston.feature_names)
y = pd.DataFrame(boston.target,columns=['MEDV'])

# %%
X
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# ...

# %%
boston.DESCR
# Out:
# "Boston House Prices dataset\n===========================\n\nNotes\n------\nData Set Characteristics:  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive\n    \n    :Median Value (attribute 14) is usually the target\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate per $10,000
# ...

# %% [markdown]
# このデータセットは何のデータセットであるか(何のために作成されたか、誰が作成したか、何年に作成されたか)
# A.米国ボストン市郊外における地域別の住宅価格のデータセット。住宅価格の回帰分析を行うために作成された。Harrison, D. and Rubinfeld, D.Lが作成。1993に作成。
#
#
# それぞれのカラムは何を表しているのか
# A.
# CRIM	人口 1 人当たりの犯罪発生数
# ZN	25,000 平方フィート以上の住居区画の占める割合
# INDUS	小売業以外の商業が占める面積の割合
# CHAS	チャールズ川によるダミー変数 (1: 川の周辺, 0: それ以外)
# NOX	NOx の濃度
# RM	住居の平均部屋数
# AGE	1940 年より前に建てられた物件の割合
# DIS	5 つのボストン市の雇用施設からの距離 (重み付け済)
# RAD	環状高速道路へのアクセスしやすさ
# TAX	$10,000 ドルあたりの不動産税率の総計
# PTRATIO	町毎の児童と教師の比率
# B	町毎の黒人 (Bk) の比率を次の式で表したもの。 1000(Bk – 0.63)^2
# LSTAT	給与の低い職業に従事する人口の割合 (%)

# %%
#一変数の可視化
X.describe()#全体のカウント、平均、標準偏差、最小値、最大値
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.593761   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.596783   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.647423   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
X.info()#欠損値やどのようなカラムがあるかを把握
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null float64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null float64
# TAX        506 non-null float64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# dtypes: float64(13)
# memory usage: 51.5 KB

# %% [markdown]
# 前処理に関して気をつけるべき点
# A.カラムによって標準偏差や平均が違うため、正規化を行わないと正常なモデルができない可能性がある。
#
# 機械学習の手法選択に活かせること
# A.ラベルが用意されていて、各カラムの値が連続した数値のため、教師あり学習の回帰分析の手法が当てはまる。
#
# 機械学習の特徴選択について考えられること
# A.標準偏差が大きいカラムの方が変動が大きく学習しやすい可能性がある。

# %%
#二変数の可視化　相関
import seaborn as sns
a = pd.concat([X,y],axis=1)
pd.DataFrame.corr(a)
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.199458  0.404471 -0.055295  0.417521 -0.219940  0.350784
# ZN      -0.199458  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.404471 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055295 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.417521 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219940  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.350784 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.377904  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.622029 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.579564 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.288250 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %% [markdown]
# そもそも相関とは何か
# A.２つ以上の物事の、どちらか一方が変われば他方もそれに連れて変わるよいうな関係を持つこと。
#
# MEDVにもっとも相関があると出力された変数を3つほどあげよ
# A.LSTAT(-0.737663),RM(0.695360),PTRATIO(-0.507787)
#
# 相関がある変数を判明させることでどのように利用できそうか考察せよ（調査せよ）
# A.特徴量選択の際に入れる入れないの判断材料になる。

# %% [markdown]
# 相関の注意点について記述せよ
# 相関が正しく2変数の関係を表していない時がある、それはどのような場合か
# その場合、どのような手段によって、確認するべきか
# A.
# ①外れ値がある場合。外れ値の影響を受けやすい。その場合は散布図を見て確認する。
# ②散布図が非線形の場合。相関係数は変数間の線形な関係を前提としているため線形でないなら相関非を用いるべき。
# ③分割相関の場合。その場合、分割する前のデータから相関係数を出すべき。

# %%
#二変数の可視化　プロット
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(X['LSTAT'],y)
plt.xlabel('LSTAT')
plt.ylabel('MEDV')
plt.title('MEDV & LSTAT')
plt.show()

plt.scatter(X['RM'],y)
plt.xlabel('RM')
plt.ylabel('MEDV')
plt.title('MEDV & RM')
plt.show()

plt.scatter(X['PTRATIO'],y)
plt.xlabel('PTRATIO')
plt.ylabel('MEDV')
plt.title('MEDV & PTRATIO')
plt.show()

# %% [markdown]
# 二変数の可視化について記述せよ　プロット
# LSTATとRMはMEDVに対し相関があるが、PTRATIOはない。

# %%
#データセット分割
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
#学習
from sklearn.tree import DecisionTreeRegressor
tree_1 = DecisionTreeRegressor(max_depth=1)
tree_2 = DecisionTreeRegressor(max_depth=2)
tree_3 = DecisionTreeRegressor(max_depth=3)

tree_1.fit(X_train,y_train)
tree_2.fit(X_train,y_train)
tree_3.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=3, max_features=None,
#            max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
#決定係数
score_1 = tree_1.score(X_test,y_test)
score_2 = tree_2.score(X_test,y_test)
score_3 = tree_3.score(X_test,y_test)
print(score_1)
print(score_2)
print(score_3)
# Out:
# 0.246184371908
# 0.565186116341
# 0.587730357252

# %%
#学習曲線
import numpy as np
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    Generate a simple plot of the test and training learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : int, cross-validation generator or an iterable, optional
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:
          - None, to use the default 3-fold cross-validation,
          - integer, to specify the number of folds.
          - An object to be used as a cross-validation generator.
          - An iterable yielding train/test splits.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
    """
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")

# %%
#メソッド呼び出し
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit
from sklearn.tree import DecisionTreeRegressor



title = "Learning Curves (DecisionTreeRegressor)"
# Cross validation with 100 iterations to get smoother mean test and train
# score curves, each time with 20% data randomly selected as a validation set.
cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)

for degree in range(1,11):
    estimator = DecisionTreeRegressor(max_depth=degree)
    plot_learning_curve(estimator, title,X , y, ylim=(0.3, 1.01), cv=cv, n_jobs=4)
# Out:
# Automatically created module for IPython interactive environment

# %% [markdown]
# 学習曲線について記述せよ
# High varianceとは何か
# A.過学習の状態。
#
# High Biasとは何か
# A.未学習の状態。
#
# もっとも結果が良いと思われた深さをひとつ選択せよ
# A.depth=3
#
# なぜその深さが最も良いか記述せよ
# A.過学習具合が小さく、テストデータに対するスコアもそれ以降の深さのものと比較してもそんなに悪くないため。
#
# その最も結果が良いと思われる深さにおいて、データ数を増やしていくと、さらに結果は良くなるか記述せよ
# A.よくなる。データ数を増やせばクロスバリデーションの数が増えるため、過学習が抑えられ決定係数も上がる。

# %%
#グリッドサーチ
from sklearn.metrics import r2_score, make_scorer#決定係数
from sklearn.model_selection import GridSearchCV

regressor = DecisionTreeRegressor()
params = {"max_depth": list(range(1,11))}
scoring_fnc = make_scorer(r2_score)
grid = GridSearchCV(estimator=regressor, param_grid=params, scoring=scoring_fnc,cv=5)#cs=5は交差検証の回数
grid.fit(X_train,y_train)
print(grid.best_params_)
# Out:
# {'max_depth': 7}

# %% [markdown]
# グリッドサーチとは何か
# A.取りうる範囲のハイパーパラメータを探索する。ハイパーパラメータを自動的に最適化してくれる機能。
#
# グリッドサーチと同じようにハイパーパラメーターを探索する手法を挙げよ
# A.ランダムサーチ
#
# その手法は、グリッドサーチと比べて、どの点で優れているか、どのように使い分けるべきか
# A.サーチにかかる時間を削減できる。ハイパーパラメータの候補が多い際はランダムサーチの方が良い。

# %%
#Kfoldの折りたたみの回数を3回と10回へ変更
grid_3 = GridSearchCV(estimator=regressor, param_grid=params, scoring=scoring_fnc,cv=3)
grid_3.fit(X_train,y_train)
print(grid_3.best_params_)

grid_10 = GridSearchCV(estimator=regressor, param_grid=params, scoring=scoring_fnc,cv=10)
grid_10.fit(X_train,y_train)
print(grid_10.best_params_)

#評価方法を平均二乗誤差に変更
from sklearn.metrics import mean_squared_error
scoring_func_2 = make_scorer(mean_squared_error)
grid_mse = GridSearchCV(estimator=regressor,param_grid=params, scoring=scoring_func_2,cv=5)
grid_mse.fit(X_train,y_train)
print(grid_mse.best_params_)
# Out:
# {'max_depth': 4}
# {'max_depth': 7}
# {'max_depth': 1}

# %%
#テスト
x2=X.loc[:,['LSTAT','RM']].as_matrix()
X_train,X_test,y_train,y_test = train_test_split(x2,y,test_size=0.4,random_state=0)
tree_4 = DecisionTreeRegressor(max_depth=4,random_state=0)
tree_4.fit(X_train,y_train)
score_test = tree_4.score(X_test,y_test)
print(score_test)
# Out:
# 0.71647289772
